# %%
import pandas as pd
from data_profiling import ProfileReport

csv_name = "4_eea_co2_emissions_from_passenger_cars-001.csv"
path = f"../data/{csv_name}"
df = pd.read_csv(path, usecols=["VFN", "Mh", "T", "Va", "Ve", "Mk", "Cn", "m (kg)", "Ewltp (g/km)", "Ft", "Fm", "ec (cm3)", "ep (KW)", "z (Wh/km)", "year"])
profile = ProfileReport(df, title=f"Data Profile: {csv_name}")
profile.to_file("eea_co2_emissions_from_passenger_cars-001.html")
